# %% [markdown]
# # Prediction using Supervised ML

# %% [markdown]
# ##### Prompt
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### Social Media
# Github - https://github.com/VarunBhattacharya/TheSparkFoundation_Supervised_ML
# <br>LinkedIn - https://www.linkedin.com/in/varunbhattacharya/
# <br>Instagram - https://www.instagram.com/varunbhattacharya.in/

# %% [markdown]
# ##### Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %% [markdown]
# ##### Load the Dataset

# %%
df = pd.read_csv('Dataset.csv')

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# ##### Information about dataset

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# ##### Training the dataset

# %%
#Differentiating between given train data and outcome data
X = df['Hours'].values.reshape(-1,1)
y = df['Scores'].values.reshape(-1,1)

# %%
#Split the data into 70% train and 30% test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %% [markdown]
# ##### Model - Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([[69.11660197],
#        [91.47446999],
#        [28.2891908 ],
#        [26.34502837],
#        [88.55822634],
#        [59.39578979],
#        [28.2891908 ],
#        [16.62421618]])

# %% [markdown]
# ##### Accuracy scores of predicted value

# %%
print('Mean Squarred Error: ', mean_squared_error(y_test,y_pred))
print('Root Mean Squarred Error: ', np.sqrt(mean_squared_error(y_test,y_pred)))
print('R2 Score: ' , r2_score(y_test,y_pred) * 100)
# Out:
# Mean Squarred Error:  18.278980896571674
# Root Mean Squarred Error:  4.275392484506151
# R2 Score:  97.7604434156892

# %% [markdown]
# ##### Creating a new dataframe with the actual and predicted values

# %%
df_new = pd.DataFrame({'Actual':y_test.flatten(), 'Predicted':y_pred.flatten()})
df_new.head()
# Out:
#    Actual  Predicted
# 0      76  69.116602
# 1      88  91.474470
# 2      30  28.289191
# 3      30  26.345028
# 4      95  88.558226

# %% [markdown]
# ##### Visualizing the data

# %%
#Actual Data Points
df.plot(x = 'Hours', y = 'Scores', style = 'x')  
plt.title('Hours vs Scores')  
plt.xlabel('Study Hours')  
plt.ylabel('Scores')
plt.grid()
plt.show()

# %%
#Plotting the linear regression line
line = lr.coef_*X + lr.intercept_

df.plot(x = 'Hours', y = 'Scores', style = 'x')
plt.plot(X, line, color = 'green');
plt.title('Hours vs Scores')  
plt.xlabel('Study Hours')  
plt.ylabel('Scores')
plt.grid()
plt.show()

# %% [markdown]
# ##### Predicted score

# %%
lrCoef = list(lr.coef_)
lrIntr = list(lr.intercept_)
regLine = 'scores = ' + str(lrCoef[0][0]) + ' * hours + ' + str(lrIntr[0])
print(f'The regression line for the above scenario is: {regLine}.')
# Out:
# The regression line for the above scenario is: scores = 9.72081218274112 * hours + 2.0429979098238107.

# %%
givenHours = 9.25

# %%
predScore = lrCoef[0][0] * givenHours + lrIntr[0]
print(f'The predicted score for study of {givenHours} hours is: {predScore}.')
# Out:
# The predicted score for study of 9.25 hours is: 91.96051060017918.

# %% [markdown]
# #### ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                                                         Done By:
#                                                                                                         Varun Bhattacharya
